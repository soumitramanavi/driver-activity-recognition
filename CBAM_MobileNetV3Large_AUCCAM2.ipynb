# %% [markdown]
# ### **Mount Google Drive:**

# %%
#reference : https://stackoverflow.com/questions/62117483/import-module-in-google-colab-from-google-drive-python
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### **Imports:**

# %%
#keras imports
import tensorflow as tf
from tensorflow import keras
from keras import layers, models

#keras layers
from tensorflow.keras.layers import GlobalAveragePooling2D, GlobalMaxPooling2D, Reshape, Dense, Input
from tensorflow.keras.layers import Activation, Concatenate, Conv2D, Multiply
from tensorflow.keras.layers import Layer, Conv2D, GlobalAveragePooling2D, Dense, Multiply, Add, Reshape, Permute, Activation,Dropout,BatchNormalization,MaxPooling2D
from tensorflow.keras.regularizers import l2

#keras applications
from tensorflow.keras.applications import MobileNetV3Large
from tensorflow.keras.applications.mobilenet_v3 import preprocess_input

# utils and pre-processing
from tensorflow.keras.utils import load_img, img_to_array
from tensorflow.keras.applications.mobilenet import preprocess_input


# image load, display
import numpy as np
import pandas as pd
import os
from PIL import Image
import matplotlib.pyplot as plt

# %% [markdown]
# ### **Defining batch and image size:**

# %%
import tensorflow as tf
# Define the data directory and other parameters
data_dir = '/content/drive/MyDrive/AUC_DatasetV2/Camera_2/train'

batch_size = 40
image_size = (224, 224)

# %% [markdown]
# ### **Data Augmentation using Image Generator:**

# %%
# Create an instance of the ImageDataGenerator
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
        rotation_range=5,
        zoom_range=0.2,
        width_shift_range=0.1,
        height_shift_range=0.1,
        shear_range=0.05,
        horizontal_flip=False,
        fill_mode="nearest",
        validation_split=0.20)

# Create a TensorFlow Dataset from the State Farm dataset directory
train_dataset = train_datagen.flow_from_directory(
    data_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    color_mode="rgb",
    subset='training',
    shuffle=True,
    seed=42
)
val_dataset = train_datagen.flow_from_directory(
    data_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    color_mode="rgb",
    subset='validation',
    shuffle=True,
    seed=42
)
# Out:
# Found 1600 images belonging to 10 classes.
# Found 400 images belonging to 10 classes.

# %% [markdown]
# ### **Display Augmented Images:**

# %%
# reference:https://www.tensorflow.org/tutorials/images/classification
plt.figure(figsize=(10, 10))
for i in range(3):
    augmented_img, _ = next(train_dataset)
    plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_img[0].astype(np.uint8))
    plt.axis('off')
plt.show()

# %% [markdown]
# ### **Convolutional Block Attention Mechanism:**
#
#
# *   Implemented spatial and channel attention
# *   Convolutional 2D layer of filter = 1
# *   Kernel size - 3x3

# %%
#reference: https://github.com/nikhilroxtomar/Attention-Mechanism-Implementation/blob/main/TensorFlow/cbam.py
def channel_attention_module(x, ratio=2):
    batch, _, _, channel = x.shape

    ## Shared layers
    l1 = Dense(channel//ratio, activation="relu", use_bias=False)
    l2 = Dense(channel, use_bias=False)

    ## Global Average Pooling 2D
    x1 = GlobalAveragePooling2D()(x)
    x1 = l1(x1)
    x1 = l2(x1)

    ## Global Max Pooling 2D
    x2 = GlobalMaxPooling2D()(x)
    x2 = l1(x2)
    x2 = l2(x2)

    ## Add both the features and pass through sigmoid
    feats = x1 + x2
    feats = Activation("sigmoid")(feats)
    feats = Multiply()([x, feats])

    return feats

def spatial_attention_module(x):
    ## Average Pooling
    x1 = tf.reduce_mean(x, axis=-1)
    x1 = tf.expand_dims(x1, axis=-1)

    ## Max Pooling
    x2 = tf.reduce_max(x, axis=-1)
    x2 = tf.expand_dims(x2, axis=-1)

    ## Concatenat both the features
    feats = Concatenate()([x1, x2])
    ## Conv 2D layer, filter size = 1
    feats = Conv2D(1, kernel_size=(3, 3), padding="same", activation="sigmoid")(feats)
    feats = Multiply()([x, feats])

    return feats

def cbam(x):
    x = channel_attention_module(x)
    x = spatial_attention_module(x)
    return x

# %% [markdown]
# ### **Load pre-trained MobileNetV3Large model. Fine tuning the model with hyperparameter settings.**
#
#
#
# *   Input = (224,224,3)
# *   GlobalAveragePooling2D
# *   Dense Layers 512-256
# *   Dropout value - 0.4
# *   Regularizer - L2(0.01)
# *   Unfreeze - last 18 layers

# %%
# Load the pre-trained MobileNetV3 model
#reference: https://www.tensorflow.org/api_docs/python/tf/keras/applications/MobileNetV3Large
base_model = MobileNetV3Large(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
for layer in base_model.layers[-18:]:
    layer.trainable = True
# Create a new input tensor for the model
inputs = tf.keras.Input(shape=(224, 224, 3))

# Output of the MobileNetV3 model
mobilenet_output = base_model(inputs)

# Apply CBAM on top of MobileNetV3 output
cbam_output = cbam(mobilenet_output)

# Classification head
x = GlobalAveragePooling2D()(cbam_output)
x = BatchNormalization()(x)

x = Dense(512, activation='relu',kernel_regularizer=l2(0.01))(x)
x = Dropout(0.4)(x)
x = Dense(256, activation='relu',kernel_regularizer=l2(0.01))(x)
x = Dropout(0.4)(x)

outputs = Dense(10, activation='softmax')(x)
model = tf.keras.Model(inputs=inputs, outputs=outputs)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  MobilenetV3large (Functional)  (None, 7, 7, 960)    2996352     ['input_2[0][0]']
#
#  global_average_pooling2d (Glob  (None, 960)         0           ['MobilenetV3large[0][0]']
#  alAveragePooling2D)
#
#  global_max_pooling2d (GlobalMa  (None, 960)         0           ['MobilenetV3large[0][0]']
#  xPooling2D)
#
#  dense (Dense)                  (None, 480)          460800      ['global_average_pooling2d[0][0]'
#                                                                  , 'global_max_pooling2d[0][0]']
#
#  dense_1 (Dense)                (None, 960)          460800      ['dense[0][0]',
#                                                                   'dense[1][0]']
#
#  tf.__operators__.add_28 (TFOpL  (None, 960)         0           ['dense_1[0][0]',
#  ambda)                                                           'dense_1[1][0]']
#
#  activation (Activation)        (None, 960)          0           ['tf.__operators__.add_28[0][0]']
#
#  multiply_20 (Multiply)         (None, 7, 7, 960)    0           ['MobilenetV3large[0][0]',
#                                                                   'activation[0][0]']
#
#  tf.math.reduce_mean (TFOpLambd  (None, 7, 7)        0           ['multiply_20[0][0]']
#  a)
#
#  tf.math.reduce_max (TFOpLambda  (None, 7, 7)        0           ['multiply_20[0][0]']
#  )
#
#  tf.expand_dims (TFOpLambda)    (None, 7, 7, 1)      0           ['tf.math.reduce_mean[0][0]']
#
#  tf.expand_dims_1 (TFOpLambda)  (None, 7, 7, 1)      0           ['tf.math.reduce_max[0][0]']
#
#  concatenate (Concatenate)      (None, 7, 7, 2)      0           ['tf.expand_dims[0][0]',
#                                                                   'tf.expand_dims_1[0][0]']
#
#  conv2d (Conv2D)                (None, 7, 7, 1)      19          ['concatenate[0][0]']
#
#  multiply_21 (Multiply)         (None, 7, 7, 960)    0           ['multiply_20[0][0]',
#                                                                   'conv2d[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 960)         0           ['multiply_21[0][0]']
#  obalAveragePooling2D)
#
#  batch_normalization (BatchNorm  (None, 960)         3840        ['global_average_pooling2d_1[0][0
#  alization)                                                      ]']
#
#  dense_2 (Dense)                (None, 512)          492032      ['batch_normalization[0][0]']
#
#  dropout (Dropout)              (None, 512)          0           ['dense_2[0][0]']
#
#  dense_3 (Dense)                (None, 256)          131328      ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 256)          0           ['dense_3[0][0]']
#
#  dense_4 (Dense)                (None, 10)           2570        ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 4,547,741
# Trainable params: 4,521,421
# Non-trainable params: 26,320
# __________________________________________________________________________________________________

# %% [markdown]
# ### **Model Compilation:**
#
#
# *   Adam Optimiser - learning rate = 0.001
#
# *   Loss - Categorical crossentropy
# *   Metrics - Accuracy
#
#
# *   Early Stopping - Patience = 5

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
#reference: https://keras.io/api/callbacks/model_checkpoint/
# Compile the model
model.compile(tf.keras.optimizers.Adam(learning_rate=0.001), loss='categorical_crossentropy',metrics=['accuracy'])
checkpointer = ModelCheckpoint('/content/drive/MyDrive/best_models/edited_img1224x224_mobilenetV3_unfreeze-18_batch_cbam3x3_512_256_adam1e3_batchsize40_l2_0.01__d0.4_aucV2CAM2_V1.0.hdf5', monitor='val_loss', mode='min', verbose=1, save_best_only=True)
es = EarlyStopping(monitor='val_loss',patience=5, min_delta = 0.001, verbose = 1,  restore_best_weights=True)

# %% [markdown]
# ### **Model Training:**
#
# *   Epochs = 25

# %%
# Training the model
model.fit(train_dataset,
    steps_per_epoch=train_dataset.samples // train_dataset.batch_size,
    epochs=25,
    validation_data=val_dataset,
    validation_steps=val_dataset.samples // val_dataset.batch_size,callbacks=[es,checkpointer])
# Out:
# Epoch 1/25
# 40/40 [==============================] - ETA: 0s - loss: 10.7293 - accuracy: 0.2850
# Epoch 1: val_loss improved from inf to 9.48402, saving model to /content/drive/MyDrive/best_models/img1224x224_mobilenetV3_unfreeze-18_batch_cbam3x3_512_256_adam1e3_batchsize40_l2_0__d0.4_aucV2CAM2_V1.0.hdf5
# 40/40 [==============================] - 75s 1s/step - loss: 10.7293 - accuracy: 0.2850 - val_loss: 9.4840 - val_accuracy: 0.1650
# Epoch 2/25
# 40/40 [==============================] - ETA: 0s - loss: 6.7932 - accuracy: 0.7925
# Epoch 2: val_loss improved from 9.48402 to 7.53850, saving model to /content/drive/MyDrive/best_models/img1224x224_mobilenetV3_unfreeze-18_batch_cbam3x3_512_256_adam1e3_batchsize40_l2_0__d0.4_aucV2CAM2_V1.0.hdf5
# 40/40 [==============================] - 54s 1s/step - loss: 6.7932 - accuracy: 0.7925 - val_loss: 7.5385 - val_accuracy: 0.3175
# Epoch 3/25
# 40/40 [==============================] - ETA: 0s - loss: 4.5476 - accuracy: 0.9531
# Epoch 3: val_loss improved from 7.53850 to 5.84887, saving model to /content/drive/MyDrive/best_models/img1224x224_mobilenetV3_unfreeze-18_batch_cbam3x3_512_256_adam1e3_batchsize40_l2_0__d0.4_aucV2CAM2_V1.0.hdf5
# 40/40 [==============================] - 53s 1s/step - loss: 4.5476 - accuracy: 0.9531 - val_loss: 5.8489 - val_accuracy: 0.4150
# Epoch 4/25
# 40/40 [==============================] - ETA: 0s - loss: 3.1363 - accuracy: 0.9750
# Epoch 4: val_loss improved from 5.84887 to 4.90178, saving model to /content/drive/MyDrive/best_models/img1224x224_mobilenetV3_unfreeze-18_batch_cbam3x3_512_256_adam1e3_batchsize40_l2_0__d0.4_aucV2CAM2_V1.0.hdf5
# 40/40 [==============================] - 53s 1s/step - loss: 3.1363 - accuracy: 0.9750 - val_loss: 4.9018 - val_accuracy: 0.4125
# Epoch 5/25
# 40/40 [==============================] - ETA: 0s - loss: 2.1216 - accuracy: 0.9837
# Epoch 5: val_loss improved from 4.90178 to 3.83330, saving model to /content/drive/MyDrive/best_models/img1224x224_mobilenetV3_unfreeze-18_batch_cbam3x3_512_256_adam1e3_batchsize40_l2_0__d0.4_aucV2CAM2_V1.0.hdf5
# 40/40 [==============================] - 52s 1s/step - loss: 2.1216 - accuracy: 0.9837 - val_loss: 3.8333 - val_accuracy: 0.4575
# Epoch 6/25
# 40/40 [==============================] - ETA: 0s - loss: 1.4219 - accuracy: 0.9894
# Epoch 6: val_loss improved from 3.83330 to 2.96163, saving model to /content/drive/MyDrive/best_models/img1224x224_mobilenetV3_unfreeze-18_batch_cbam3x3_512_256_adam1e3_batchsize40_l2_0__d0.4_aucV2CAM2_V1.0.hdf5
# 40/40 [==============================] - 54s 1s/step - loss: 1.4219 - accuracy: 0.9894 - val_loss: 2.9616 - val_accuracy: 0.4700
# Epoch 7/25
# 40/40 [==============================] - ETA: 0s - loss: 0.9390 - accuracy: 0.9937
# Epoch 7: val_loss improved from 2.96163 to 2.87668, saving model to /content/drive/MyDrive/best_models/img1224x224_mobilenetV3_unfreeze-18_batch_cbam3x3_512_256_adam1e3_batchsize40_l2_0__d0.4_aucV2CAM2_V1.0.hdf5
# 40/40 [==============================] - 45s 1s/step - loss: 0.9390 - accuracy: 0.9937 - val_loss: 2.8767 - val_accuracy: 0.3975
# Epoch 8/25
# 40/40 [==============================] - ETA: 0s - loss: 0.6304 - accuracy: 0.9950
# Epoch 8: val_loss improved from 2.87668 to 2.05867, saving model to /content/drive/MyDrive/best_models/img1224x224_mobilenetV3_unfreeze-18_batch_cbam3x3_512_256_adam1e3_batchsize40_l2_0__d0.4_aucV2CAM2_V1.0.hdf5
# 40/40 [==============================] - 46s 1s/step - loss: 0.6304 - accuracy: 0.9950 - val_loss: 2.0587 - val_accuracy: 0.5000
# Epoch 9/25
# 40/40 [==============================] - ETA: 0s - loss: 0.4171 - accuracy: 0.9994
# Epoch 9: val_loss improved from 2.05867 to 1.91447, saving model to /content/drive/MyDrive/best_models/img1224x224_mobilenetV3_unfreeze-18_batch_cbam3x3_512_256_adam1e3_batchsize40_l2_0__d0.4_aucV2CAM2_V1.0.hdf5
# 40/40 [==============================] - 45s 1s/step - loss: 0.4171 - accuracy: 0.9994 - val_loss: 1.9145 - val_accuracy: 0.5050
# Epoch 10/25
# 40/40 [==============================] - ETA: 0s - loss: 0.2895 - accuracy: 0.9987
# Epoch 10: val_loss improved from 1.91447 to 1.62873, saving model to /content/drive/MyDrive/best_models/img1224x224_mobilenetV3_unfreeze-18_batch_cbam3x3_512_256_adam1e3_batchsize40_l2_0__d0.4_aucV2CAM2_V1.0.hdf5
# 40/40 [==============================] - 45s 1s/step - loss: 0.2895 - accuracy: 0.9987 - val_loss: 1.6287 - val_accuracy: 0.5425
# Epoch 11/25
# 40/40 [==============================] - ETA: 0s - loss: 0.2064 - accuracy: 0.9987
# Epoch 11: val_loss improved from 1.62873 to 1.44609, saving model to /content/drive/MyDrive/best_models/img1224x224_mobilenetV3_unfreeze-18_batch_cbam3x3_512_256_adam1e3_batchsize40_l2_0__d0.4_aucV2CAM2_V1.0.hdf5
# 40/40 [==============================] - 44s 1s/step - loss: 0.2064 - accuracy: 0.9987 - val_loss: 1.4461 - val_accuracy: 0.5825
# Epoch 12/25
# 40/40 [==============================] - ETA: 0s - loss: 0.1537 - accuracy: 0.9994
# Epoch 12: val_loss improved from 1.44609 to 1.22048, saving model to /content/drive/MyDrive/best_models/img1224x224_mobilenetV3_unfreeze-18_batch_cbam3x3_512_256_adam1e3_batchsize40_l2_0__d0.4_aucV2CAM2_V1.0.hdf5
# 40/40 [==============================] - 46s 1s/step - loss: 0.1537 - accuracy: 0.9994 - val_loss: 1.2205 - val_accuracy: 0.6475
# Epoch 13/25
# 40/40 [==============================] - ETA: 0s - loss: 0.1219 - accuracy: 1.0000
# Epoch 13: val_loss did not improve from 1.22048
# 40/40 [==============================] - 44s 1s/step - loss: 0.1219 - accuracy: 1.0000 - val_loss: 1.2975 - val_accuracy: 0.6100
# Epoch 14/25
# 40/40 [==============================] - ETA: 0s - loss: 0.1186 - accuracy: 0.9956
# Epoch 14: val_loss did not improve from 1.22048
# 40/40 [==============================] - 44s 1s/step - loss: 0.1186 - accuracy: 0.9956 - val_loss: 1.6229 - val_accuracy: 0.5725
# Epoch 15/25
# 40/40 [==============================] - ETA: 0s - loss: 0.1239 - accuracy: 0.9950
# Epoch 15: val_loss improved from 1.22048 to 1.21255, saving model to /content/drive/MyDrive/best_models/img1224x224_mobilenetV3_unfreeze-18_batch_cbam3x3_512_256_adam1e3_batchsize40_l2_0__d0.4_aucV2CAM2_V1.0.hdf5
# 40/40 [==============================] - 45s 1s/step - loss: 0.1239 - accuracy: 0.9950 - val_loss: 1.2126 - val_accuracy: 0.6825
# Epoch 16/25
# 40/40 [==============================] - ETA: 0s - loss: 0.1048 - accuracy: 0.9975
# Epoch 16: val_loss did not improve from 1.21255
# 40/40 [==============================] - 44s 1s/step - loss: 0.1048 - accuracy: 0.9975 - val_loss: 1.2594 - val_accuracy: 0.6650
# Epoch 17/25
# 40/40 [==============================] - ETA: 0s - loss: 0.1246 - accuracy: 0.9900
# Epoch 17: val_loss did not improve from 1.21255
# 40/40 [==============================] - 44s 1s/step - loss: 0.1246 - accuracy: 0.9900 - val_loss: 2.6036 - val_accuracy: 0.4675
# Epoch 18/25
# 40/40 [==============================] - ETA: 0s - loss: 0.1380 - accuracy: 0.9887
# Epoch 18: val_loss did not improve from 1.21255
# 40/40 [==============================] - 44s 1s/step - loss: 0.1380 - accuracy: 0.9887 - val_loss: 3.9736 - val_accuracy: 0.2050
# Epoch 19/25
# 40/40 [==============================] - ETA: 0s - loss: 0.1533 - accuracy: 0.9856
# Epoch 19: val_loss did not improve from 1.21255
# 40/40 [==============================] - 44s 1s/step - loss: 0.1533 - accuracy: 0.9856 - val_loss: 3.0219 - val_accuracy: 0.2950
# Epoch 20/25
# 40/40 [==============================] - ETA: 0s - loss: 0.1984 - accuracy: 0.9806Restoring model weights from the end of the best epoch: 15.
#
# Epoch 20: val_loss did not improve from 1.21255
# 40/40 [==============================] - 44s 1s/step - loss: 0.1984 - accuracy: 0.9806 - val_loss: 2.8522 - val_accuracy: 0.4350
# Epoch 20: early stopping

# %% [markdown]
# ### **Model Training and Validation Loss:**

# %%
fig = plt.figure(figsize = (15,8))
plt.plot(model.history.history['loss'])
plt.plot(model.history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['training loss','validation loss'], loc='upper right')
plt.show()

# %% [markdown]
# ### **Model Training and Validation Accuracy:**

# %%
fig = plt.figure(figsize = (15,8))
plt.plot(model.history.history['accuracy'])
plt.plot(model.history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['training accuracy','validation accuracy'], loc='upper right')
plt.show()

# %% [markdown]
# ### **Load the best model:**

# %%
# Load the best model from the saved checkpoint
best_model = tf.keras.models.load_model('/content/drive/MyDrive/best_models/edited_img1224x224_mobilenetV3_unfreeze-18_batch_cbam3x3_512_256_adam1e3_batchsize40_l2_0.01__d0.4_aucV2CAM2_V1.0.hdf5')

# %% [markdown]
# ### **Load test samples:**

# %%
test_dir1 = "/content/drive/MyDrive/AUC_DatasetV2/Camera_2/test"
test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=None)
test_generator = test_datagen.flow_from_directory(
    test_dir1,
    target_size=image_size,
    batch_size=40,
    class_mode='categorical',
    color_mode='rgb',
    shuffle=False
)
# Out:
# Found 800 images belonging to 10 classes.

# %% [markdown]
# ### **Evaluate the model:**

# %%
test_loss, test_accuracy = best_model.evaluate(test_generator,steps=test_generator.samples // test_generator.batch_size,verbose=1)
print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
# Out:
# 20/20 [==============================] - 129s 7s/step - loss: 1.1645 - accuracy: 0.7412
# Test Loss: 1.1644872426986694
# Test Accuracy: 0.7412499785423279

# %% [markdown]
# ### **Confusion Matrix - Test Data**

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

true_labels = test_generator.classes

num_classes = len(test_generator.class_indices)
predictions = best_model.predict(test_generator)
predicted_labels = np.argmax(predictions, axis=1)

# Create the confusion matrix
conf_matrix_test = confusion_matrix(true_labels, predicted_labels)

#reference: https://stackoverflow.com/questions/61526287/how-to-add-correct-labels-for-seaborn-confusion-matrix
# Plot the confusion matrix heatmap with counts inside
plt.figure(figsize=(10, 8))
sns.set(font_scale=1.2)
sns.heatmap(conf_matrix_test, annot=True, fmt='d', cmap="Blues", xticklabels=test_generator.class_indices.keys(), yticklabels=test_generator.class_indices.keys())
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# 20/20 [==============================] - 6s 250ms/step

# %% [markdown]
# ### **Test Accuracy per Class:**

# %%
#reference:https://stackoverflow.com/questions/39770376/scikit-learn-get-accuracy-scores-for-each-class
def calculate_per_class_accuracy_test(conf_matrix):
    num_classes = conf_matrix.shape[0]
    accuracy_dict = {}

    for i in range(num_classes):
        true_positive = conf_matrix[i, i]
        total_predictions = sum(conf_matrix[i, :])
        accuracy = true_positive / total_predictions

        accuracy_dict[i] = accuracy

    return accuracy_dict

per_class_accuracy = calculate_per_class_accuracy_test(conf_matrix_test)
class_names = ["c0", "c1", "c2","c3","c4","c5","c6","c7","c8","c9"]  # Replace with your class names

for i, class_name in enumerate(class_names):
    print(f"Accuracy for {class_name}: {per_class_accuracy[i]:.4f}")

mean_accuracy = sum(per_class_accuracy.values()) / len(per_class_accuracy)
print(f"Overall Mean Accuracy: {mean_accuracy:.4f}")
# Out:
# Accuracy for c0: 0.5375
# Accuracy for c1: 0.9750
# Accuracy for c2: 1.0000
# Accuracy for c3: 1.0000
# Accuracy for c4: 0.6625
# Accuracy for c5: 1.0000
# Accuracy for c6: 0.7500
# Accuracy for c7: 0.5000
# Accuracy for c8: 0.0000
# Accuracy for c9: 0.9875
# Overall Mean Accuracy: 0.7412

# %% [markdown]
# ### **Get Class Labels:**

# %%
def get_labels(predicted_label_index):

  if predicted_label_index == 1:
    return "Safe driving"
  elif predicted_label_index == 2:
    return "Text right"
  elif predicted_label_index == 3:
    return "Talk right"
  elif predicted_label_index == 4:
    return "Text left"
  elif predicted_label_index == 5:
    return "Audio system"
  elif predicted_label_index == 6:
    return "Drink"
  elif predicted_label_index == 7:
    return "Reach Behind"
  elif predicted_label_index == 8:
    return "Hair-Makeup"
  else:
    return "Talk to passenger"

# %% [markdown]
# ### **Check Predictions:**

# %%
image_paths = [
    '/content/drive/MyDrive/AUC_DatasetV2/Camera_2/test/c6/135604.jpg',
    '/content/drive/MyDrive/AUC_DatasetV2/Camera_2/test/c8/137329.jpg'
]

# Create a figure with multiple subplots arranged horizontally
num_images = len(image_paths)
fig, axes = plt.subplots(1, num_images, figsize=(10, 10))

# Loop through image paths
for i, img_path in enumerate(image_paths):
    # Load and preprocess the image
    my_image = load_img(img_path, target_size=(224, 224))
    my_image = img_to_array(my_image)
    my_image = np.expand_dims(my_image, axis=0)
    my_image = preprocess_input(my_image)

    # Make the prediction
    prediction_single = best_model.predict(my_image)
    predicted_label_index = np.argmax(prediction_single)

    predicted_label = get_labels(predicted_label_index)

    # Load the image using plt.imread
    img = plt.imread(img_path)

    # Plot the image on a subplot
    axes[i].imshow(img)
    axes[i].set_title(f'Prediction: {predicted_label}',size = 12)
    axes[i].axis('off')

# Adjust layout spacing between subplots
plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
