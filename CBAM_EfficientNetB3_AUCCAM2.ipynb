# %% [markdown]
# ### **Mount Google Drive:**

# %%
#reference : https://stackoverflow.com/questions/62117483/import-module-in-google-colab-from-google-drive-python
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### **Imports:**

# %%
# !pip install tensorflow==2.9

# Import TensorFlow
import tensorflow as tf
print(tf.__version__)

from tensorflow import keras
from keras import layers, models

# load, display import
import numpy as np
import pandas as pd
import os
from PIL import Image
import matplotlib.pyplot as plt

# utils and pre-processing
from tensorflow.keras.utils import load_img, img_to_array
from tensorflow.keras.applications.efficientnet import preprocess_input

#keras layers
from tensorflow.keras.layers import GlobalAveragePooling2D, GlobalMaxPooling2D, Reshape, Dense, Input
from tensorflow.keras.layers import Activation, Concatenate, Conv2D, Multiply
from tensorflow.keras.layers import Layer, Conv2D, GlobalAveragePooling2D, Dense, Multiply, Add, Reshape, Permute, Activation,Dropout,BatchNormalization
from tensorflow.keras.regularizers import l2

#keras callbacks
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
# Out:
# 2.9.0

# %% [markdown]
# ### **Defining batch and image size:**

# %%
# Define the data directory
data_dir = '/content/drive/MyDrive/AUC_DatasetV2/Camera_2/train'

batch_size = 40
image_size = (224, 224)

# %% [markdown]
# ### **Data Augmentation using Image Generator:**

# %%
# Create an instance of the ImageDataGenerator
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
        rotation_range=5,
        zoom_range=0.2,
        width_shift_range=0.1,
        height_shift_range=0.1,
        shear_range=0.05,
        horizontal_flip=False,
        fill_mode="nearest",
        validation_split=0.20)

# Create a TensorFlow Dataset from the State Farm dataset directory
train_dataset = train_datagen.flow_from_directory(
    data_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    color_mode="rgb",
    subset='training',
    shuffle=True,
    seed=42
)
val_dataset = train_datagen.flow_from_directory(
    data_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    color_mode="rgb",
    subset='validation',
    shuffle=True,
    seed=42
)
# Out:
# Found 1600 images belonging to 10 classes.
# Found 400 images belonging to 10 classes.

# %% [markdown]
# ### **Display Augmented Images:**

# %%
# reference:https://www.tensorflow.org/tutorials/images/classification
plt.figure(figsize=(10, 10))
for i in range(3):
    augmented_img, _ = next(train_dataset)
    plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_img[0].astype(np.uint8))
    plt.axis('off')
plt.show()

# %% [markdown]
# ### **Convolutional Block Attention Mechanism:**
#
#
# *   Implemented spatial and channel attention
# *   Convolutional 2D layer of filter = 1
# *   Kernel size - 3x3

# %%
#reference: https://github.com/nikhilroxtomar/Attention-Mechanism-Implementation/blob/main/TensorFlow/cbam.py
def channel_attention_module(x, ratio=8):
    batch, _, _, channel = x.shape

    ## Shared layers
    l1 = Dense(channel//ratio, activation="relu", use_bias=False)
    l2 = Dense(channel, use_bias=False)

    ## Global Average Pooling
    x1 = GlobalAveragePooling2D()(x)
    x1 = l1(x1)
    x1 = l2(x1)

    ## Global Max Pooling
    x2 = GlobalMaxPooling2D()(x)
    x2 = l1(x2)
    x2 = l2(x2)

    ## Add both the features and pass through sigmoid
    feats = x1 + x2
    feats = Activation("sigmoid")(feats)
    feats = Multiply()([x, feats])

    return feats

def spatial_attention_module(x):
    ## Average Pooling
    x1 = tf.reduce_mean(x, axis=-1)
    x1 = tf.expand_dims(x1, axis=-1)

    ## Max Pooling
    x2 = tf.reduce_max(x, axis=-1)
    x2 = tf.expand_dims(x2, axis=-1)

    ## Concatenat both the features
    feats = Concatenate()([x1, x2])
    ## Conv layer
    feats = Conv2D(1, kernel_size=(3, 3), padding="same", activation="sigmoid")(feats)
    feats = Multiply()([x, feats])

    return feats

def cbam(x):
    x = channel_attention_module(x)
    x = spatial_attention_module(x)
    return x

# %% [markdown]
# ### **Load pre-trained EfficientNetB3 model. Fine tuning the model with hyperparameter settings.**
#
#
#
# *   Input = (224,224,3)
# *   GlobalAveragePooling2D
# *   Dense Layers 512-256
# *   Dropout value - 0.4
# *   Regularizer - L2(0.01)
# *   Unfreeze - last 18 layers

# %%
# Load the pre-trained EfficientNetV3 model
#reference: https://www.tensorflow.org/api_docs/python/tf/keras/applications/efficientnet/EfficientNetB3
base_model = tf.keras.applications.efficientnet.EfficientNetB3(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
for layer in base_model.layers[-18:]:
    layer.trainable = True
# Create a new input tensor for the model
inputs = tf.keras.Input(shape=(224, 224, 3))

# Get the output of the EfficientNetB3 model
efficientNetB3_output = base_model(inputs)

# Apply CBAM on top of EfficientNetB3 output
cbam_output = cbam(efficientNetB3_output)

# Create your custom top layers
x = GlobalAveragePooling2D()(cbam_output)
x = BatchNormalization()(x)

x = Dense(512, activation='relu',kernel_regularizer=l2(0.01))(x)
x = Dropout(0.4)(x)
x = Dense(256, activation='relu',kernel_regularizer=l2(0.01))(x)
x = Dropout(0.4)(x)

outputs = Dense(10, activation='softmax')(x)
model = tf.keras.Model(inputs=inputs, outputs=outputs)
# Print model summary
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  efficientnetb3 (Functional)    (None, 7, 7, 1536)   10783535    ['input_2[0][0]']
#
#  global_average_pooling2d (Glob  (None, 1536)        0           ['efficientnetb3[0][0]']
#  alAveragePooling2D)
#
#  global_max_pooling2d (GlobalMa  (None, 1536)        0           ['efficientnetb3[0][0]']
#  xPooling2D)
#
#  dense (Dense)                  (None, 192)          294912      ['global_average_pooling2d[0][0]'
#                                                                  , 'global_max_pooling2d[0][0]']
#
#  dense_1 (Dense)                (None, 1536)         294912      ['dense[0][0]',
#                                                                   'dense[1][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 1536)        0           ['dense_1[0][0]',
#  da)                                                              'dense_1[1][0]']
#
#  activation (Activation)        (None, 1536)         0           ['tf.__operators__.add[0][0]']
#
#  multiply (Multiply)            (None, 7, 7, 1536)   0           ['efficientnetb3[0][0]',
#                                                                   'activation[0][0]']
#
#  tf.math.reduce_mean (TFOpLambd  (None, 7, 7)        0           ['multiply[0][0]']
#  a)
#
#  tf.math.reduce_max (TFOpLambda  (None, 7, 7)        0           ['multiply[0][0]']
#  )
#
#  tf.expand_dims (TFOpLambda)    (None, 7, 7, 1)      0           ['tf.math.reduce_mean[0][0]']
#
#  tf.expand_dims_1 (TFOpLambda)  (None, 7, 7, 1)      0           ['tf.math.reduce_max[0][0]']
#
#  concatenate (Concatenate)      (None, 7, 7, 2)      0           ['tf.expand_dims[0][0]',
#                                                                   'tf.expand_dims_1[0][0]']
#
#  conv2d (Conv2D)                (None, 7, 7, 1)      19          ['concatenate[0][0]']
#
#  multiply_1 (Multiply)          (None, 7, 7, 1536)   0           ['multiply[0][0]',
#                                                                   'conv2d[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 1536)        0           ['multiply_1[0][0]']
#  obalAveragePooling2D)
#
#  batch_normalization (BatchNorm  (None, 1536)        6144        ['global_average_pooling2d_1[0][0
#  alization)                                                      ]']
#
#  dense_2 (Dense)                (None, 512)          786944      ['batch_normalization[0][0]']
#
#  dropout (Dropout)              (None, 512)          0           ['dense_2[0][0]']
#
#  dense_3 (Dense)                (None, 256)          131328      ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 256)          0           ['dense_3[0][0]']
#
#  dense_4 (Dense)                (None, 10)           2570        ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 12,300,364
# Trainable params: 12,209,989
# Non-trainable params: 90,375
# __________________________________________________________________________________________________

# %% [markdown]
# ### **Model Compilation:**
#
#
# *   Adam Optimiser - learning rate = 0.001
#
# *   Loss - Categorical crossentropy
# *   Metrics - Accuracy
#
#
# *   Early Stopping - Patience = 5

# %%
# Compile the model
#reference: https://keras.io/api/callbacks/model_checkpoint/
model.compile(tf.keras.optimizers.Adam(learning_rate=0.001), loss='categorical_crossentropy',metrics=['accuracy'])
checkpointer = ModelCheckpoint('/content/drive/MyDrive/best_models/edited_img1224x224_effcnetb3_unfreeze-18_batch_cbam3x3_512_256_adam1e3_batchsize40_l2_0.01__d0.4_aucV2CAM2_V1.0.hdf5', monitor='val_loss', mode='min', verbose=1, save_best_only=True)
es = EarlyStopping(monitor='val_loss',patience=5, min_delta = 0.001, verbose = 1,  restore_best_weights=True)

# %% [markdown]
# ### **Model Training:**
#
# *   Epochs = 25

# %%
# Training the model
model.fit(train_dataset,
    steps_per_epoch=train_dataset.samples // train_dataset.batch_size,
    epochs=25,
    validation_data=val_dataset,
    validation_steps=val_dataset.samples // val_dataset.batch_size,callbacks=[es,checkpointer])
# Out:
# Epoch 1/25
# 40/40 [==============================] - ETA: 0s - loss: 11.9157 - accuracy: 0.3144
# Epoch 1: val_loss improved from inf to 10.55569, saving model to /content/drive/MyDrive/best_models/edited_img1224x224_effcnetb3_unfreeze-18_batch_cbam3x3_512_256_adam1e3_batchsize40_l2_0.01__d0.4_aucV2CAM2_V1.0.hdf5
# 40/40 [==============================] - 219s 5s/step - loss: 11.9157 - accuracy: 0.3144 - val_loss: 10.5557 - val_accuracy: 0.3175
# Epoch 2/25
# 40/40 [==============================] - ETA: 0s - loss: 7.8105 - accuracy: 0.8194
# Epoch 2: val_loss improved from 10.55569 to 7.61378, saving model to /content/drive/MyDrive/best_models/edited_img1224x224_effcnetb3_unfreeze-18_batch_cbam3x3_512_256_adam1e3_batchsize40_l2_0.01__d0.4_aucV2CAM2_V1.0.hdf5
# 40/40 [==============================] - 196s 5s/step - loss: 7.8105 - accuracy: 0.8194 - val_loss: 7.6138 - val_accuracy: 0.5250
# Epoch 3/25
# 40/40 [==============================] - ETA: 0s - loss: 5.3280 - accuracy: 0.9425
# Epoch 3: val_loss improved from 7.61378 to 5.18477, saving model to /content/drive/MyDrive/best_models/edited_img1224x224_effcnetb3_unfreeze-18_batch_cbam3x3_512_256_adam1e3_batchsize40_l2_0.01__d0.4_aucV2CAM2_V1.0.hdf5
# 40/40 [==============================] - 200s 5s/step - loss: 5.3280 - accuracy: 0.9425 - val_loss: 5.1848 - val_accuracy: 0.7150
# Epoch 4/25
# 40/40 [==============================] - ETA: 0s - loss: 3.6838 - accuracy: 0.9606
# Epoch 4: val_loss improved from 5.18477 to 4.09225, saving model to /content/drive/MyDrive/best_models/edited_img1224x224_effcnetb3_unfreeze-18_batch_cbam3x3_512_256_adam1e3_batchsize40_l2_0.01__d0.4_aucV2CAM2_V1.0.hdf5
# 40/40 [==============================] - 200s 5s/step - loss: 3.6838 - accuracy: 0.9606 - val_loss: 4.0922 - val_accuracy: 0.6125
# Epoch 5/25
# 40/40 [==============================] - ETA: 0s - loss: 2.4990 - accuracy: 0.9744
# Epoch 5: val_loss improved from 4.09225 to 3.08482, saving model to /content/drive/MyDrive/best_models/edited_img1224x224_effcnetb3_unfreeze-18_batch_cbam3x3_512_256_adam1e3_batchsize40_l2_0.01__d0.4_aucV2CAM2_V1.0.hdf5
# 40/40 [==============================] - 194s 5s/step - loss: 2.4990 - accuracy: 0.9744 - val_loss: 3.0848 - val_accuracy: 0.6675
# Epoch 6/25
# 40/40 [==============================] - ETA: 0s - loss: 1.7156 - accuracy: 0.9787
# Epoch 6: val_loss improved from 3.08482 to 2.28632, saving model to /content/drive/MyDrive/best_models/edited_img1224x224_effcnetb3_unfreeze-18_batch_cbam3x3_512_256_adam1e3_batchsize40_l2_0.01__d0.4_aucV2CAM2_V1.0.hdf5
# 40/40 [==============================] - 199s 5s/step - loss: 1.7156 - accuracy: 0.9787 - val_loss: 2.2863 - val_accuracy: 0.7175
# Epoch 7/25
# 40/40 [==============================] - ETA: 0s - loss: 1.1568 - accuracy: 0.9800
# Epoch 7: val_loss improved from 2.28632 to 2.01046, saving model to /content/drive/MyDrive/best_models/edited_img1224x224_effcnetb3_unfreeze-18_batch_cbam3x3_512_256_adam1e3_batchsize40_l2_0.01__d0.4_aucV2CAM2_V1.0.hdf5
# 40/40 [==============================] - 198s 5s/step - loss: 1.1568 - accuracy: 0.9800 - val_loss: 2.0105 - val_accuracy: 0.6950
# Epoch 8/25
# 40/40 [==============================] - ETA: 0s - loss: 0.8011 - accuracy: 0.9831
# Epoch 8: val_loss improved from 2.01046 to 1.61946, saving model to /content/drive/MyDrive/best_models/edited_img1224x224_effcnetb3_unfreeze-18_batch_cbam3x3_512_256_adam1e3_batchsize40_l2_0.01__d0.4_aucV2CAM2_V1.0.hdf5
# 40/40 [==============================] - 199s 5s/step - loss: 0.8011 - accuracy: 0.9831 - val_loss: 1.6195 - val_accuracy: 0.7200
# Epoch 9/25
# 40/40 [==============================] - ETA: 0s - loss: 0.5556 - accuracy: 0.9881
# Epoch 9: val_loss did not improve from 1.61946
# 40/40 [==============================] - 198s 5s/step - loss: 0.5556 - accuracy: 0.9881 - val_loss: 1.6650 - val_accuracy: 0.7050
# Epoch 10/25
# 40/40 [==============================] - ETA: 0s - loss: 0.4074 - accuracy: 0.9850
# Epoch 10: val_loss improved from 1.61946 to 1.03864, saving model to /content/drive/MyDrive/best_models/edited_img1224x224_effcnetb3_unfreeze-18_batch_cbam3x3_512_256_adam1e3_batchsize40_l2_0.01__d0.4_aucV2CAM2_V1.0.hdf5
# 40/40 [==============================] - 201s 5s/step - loss: 0.4074 - accuracy: 0.9850 - val_loss: 1.0386 - val_accuracy: 0.7850
# Epoch 11/25
# 40/40 [==============================] - ETA: 0s - loss: 0.3220 - accuracy: 0.9875
# Epoch 11: val_loss improved from 1.03864 to 1.01209, saving model to /content/drive/MyDrive/best_models/edited_img1224x224_effcnetb3_unfreeze-18_batch_cbam3x3_512_256_adam1e3_batchsize40_l2_0.01__d0.4_aucV2CAM2_V1.0.hdf5
# 40/40 [==============================] - 200s 5s/step - loss: 0.3220 - accuracy: 0.9875 - val_loss: 1.0121 - val_accuracy: 0.8025
# Epoch 12/25
# 40/40 [==============================] - ETA: 0s - loss: 0.2467 - accuracy: 0.9887
# Epoch 12: val_loss did not improve from 1.01209
# 40/40 [==============================] - 197s 5s/step - loss: 0.2467 - accuracy: 0.9887 - val_loss: 1.3166 - val_accuracy: 0.7525
# Epoch 13/25
# 40/40 [==============================] - ETA: 0s - loss: 0.1784 - accuracy: 0.9950
# Epoch 13: val_loss did not improve from 1.01209
# 40/40 [==============================] - 193s 5s/step - loss: 0.1784 - accuracy: 0.9950 - val_loss: 1.0572 - val_accuracy: 0.7575
# Epoch 14/25
# 40/40 [==============================] - ETA: 0s - loss: 0.1435 - accuracy: 0.9956
# Epoch 14: val_loss did not improve from 1.01209
# 40/40 [==============================] - 185s 5s/step - loss: 0.1435 - accuracy: 0.9956 - val_loss: 1.3689 - val_accuracy: 0.7000
# Epoch 15/25
# 40/40 [==============================] - ETA: 0s - loss: 0.1209 - accuracy: 0.9962
# Epoch 15: val_loss did not improve from 1.01209
# 40/40 [==============================] - 187s 5s/step - loss: 0.1209 - accuracy: 0.9962 - val_loss: 1.4186 - val_accuracy: 0.7600
# Epoch 16/25
# 40/40 [==============================] - ETA: 0s - loss: 0.1317 - accuracy: 0.9906Restoring model weights from the end of the best epoch: 11.
#
# Epoch 16: val_loss did not improve from 1.01209
# 40/40 [==============================] - 199s 5s/step - loss: 0.1317 - accuracy: 0.9906 - val_loss: 1.1602 - val_accuracy: 0.7650
# Epoch 16: early stopping

# %% [markdown]
# ### **Model Training and Validation Loss:**

# %%
fig = plt.figure(figsize = (15,8))
plt.plot(model.history.history['loss'])
plt.plot(model.history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['training loss','validation loss'], loc='upper right')
plt.show()

# %% [markdown]
# ### **Model Training and Validation Accuracy:**

# %%
fig = plt.figure(figsize = (15,8))
plt.plot(model.history.history['accuracy'])
plt.plot(model.history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['training accuracy','validation accuracy'], loc='upper right')
plt.show()

# %% [markdown]
# ### **Load the best model:**

# %%
# Load the best model from the saved checkpoint
best_model = tf.keras.models.load_model('/content/drive/MyDrive/best_models/edited_img1224x224_effcnetb3_unfreeze-18_batch_cbam3x3_512_256_adam1e3_batchsize40_l2_0.01__d0.4_aucV2CAM2_V1.0.hdf5')

# %% [markdown]
# ### **Load test samples:**

# %%
test_dir = "/content/drive/MyDrive/AUC_DatasetV2/Camera_2/test"
test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=None)
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=image_size,
    batch_size=40,
    class_mode='categorical',
    color_mode='rgb',
    shuffle=False
)
# Out:
# Found 800 images belonging to 10 classes.

# %% [markdown]
# ### **Evaluate the model:**

# %%
"test_loss, test_accuracy = model.evaluate(test_generator,steps=test_generator.samples // test_generator.batch_size,verbose=1)
print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
# Out:
# 20/20 [==============================] - 152s 8s/step - loss: 0.6841 - accuracy: 0.8675
# Test Loss: 0.6841276288032532
# Test Accuracy: 0.8675000071525574

# %% [markdown]
# ### **Confusion Matrix - Test Data**

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

true_labels = test_generator.classes

num_classes = len(test_generator.class_indices)
predictions = best_model.predict(test_generator)
predicted_labels = np.argmax(predictions, axis=1)

# Create the confusion matrix
conf_matrix_test = confusion_matrix(true_labels, predicted_labels)

#reference: https://stackoverflow.com/questions/61526287/how-to-add-correct-labels-for-seaborn-confusion-matrix
# Plot the confusion matrix heatmap with counts inside
plt.figure(figsize=(10, 8))
sns.set(font_scale=1.2)
sns.heatmap(conf_matrix_test, annot=True, fmt='d', cmap="Blues", xticklabels=test_generator.class_indices.keys(), yticklabels=test_generator.class_indices.keys())
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# 20/20 [==============================] - 22s 947ms/step

# %% [markdown]
# ### **Test Accuracy per Class:**

# %%
#reference:https://stackoverflow.com/questions/39770376/scikit-learn-get-accuracy-scores-for-each-class
def calculate_per_class_accuracy_test(conf_matrix):
    num_classes = conf_matrix.shape[0]
    accuracy_dict = {}

    for i in range(num_classes):
        true_positive = conf_matrix[i, i]
        total_predictions = sum(conf_matrix[i, :])
        accuracy = true_positive / total_predictions

        accuracy_dict[i] = accuracy

    return accuracy_dict

per_class_accuracy = calculate_per_class_accuracy_test(conf_matrix_test)
class_names = ["c0", "c1", "c2","c3","c4","c5","c6","c7","c8","c9"]  # Replace with your class names

for i, class_name in enumerate(class_names):
    print(f"Accuracy for {class_name}: {per_class_accuracy[i]:.4f}")

mean_accuracy = sum(per_class_accuracy.values()) / len(per_class_accuracy)
print(f"Overall Mean Accuracy: {mean_accuracy:.4f}")
# Out:
# Accuracy for c0: 0.9125
# Accuracy for c1: 0.9625
# Accuracy for c2: 0.7750
# Accuracy for c3: 0.9875
# Accuracy for c4: 0.9000
# Accuracy for c5: 1.0000
# Accuracy for c6: 0.8375
# Accuracy for c7: 1.0000
# Accuracy for c8: 0.3250
# Accuracy for c9: 0.9750
# Overall Mean Accuracy: 0.8675

# %% [markdown]
# ### **Get Class Labels:**

# %%
def get_labels(predicted_label_index):

  if predicted_label_index == 1:
    return "Safe driving"
  elif predicted_label_index == 2:
    return "Text right"
  elif predicted_label_index == 3:
    return "Talk right"
  elif predicted_label_index == 4:
    return "Text left"
  elif predicted_label_index == 5:
    return "Audio system"
  elif predicted_label_index == 6:
    return "Drink"
  elif predicted_label_index == 7:
    return "Reach Behind"
  elif predicted_label_index == 8:
    return "Hair-Makeup"
  else:
    return "Talk to passenger"

# %% [markdown]
# ### **Check Predictions:**

# %%
image_paths = [
    '/content/drive/MyDrive/AUC_DatasetV2/Camera_2/test/c7/66359.jpg',
    '/content/drive/MyDrive/AUC_DatasetV2/Camera_2/test/c5/134628.jpg'
]
# Create a figure with multiple subplots arranged horizontally
num_images = len(image_paths)
fig, axes = plt.subplots(1, num_images, figsize=(10, 10))

# Loop through image paths
for i, img_path in enumerate(image_paths):
    # Load and preprocess the image
    my_image = load_img(img_path, target_size=(224, 224))
    my_image = img_to_array(my_image)
    my_image = np.expand_dims(my_image, axis=0)
    my_image = preprocess_input(my_image)

    # Make the prediction
    prediction_single = model.predict(my_image)
    predicted_label_index = np.argmax(prediction_single)

    predicted_label = get_labels(predicted_label_index)

    # Load the image using plt.imread
    img = plt.imread(img_path)

    # Plot the image on a subplot
    axes[i].imshow(img)
    axes[i].set_title(f'Prediction: {predicted_label}',size = 12)
    axes[i].axis('off')

# Adjust layout spacing between subplots
plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 105ms/step
